# %% [markdown]
# <a href="https://colab.research.google.com/github/sanskarahamana/APS-LAB/blob/main/lab_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Travelling Salesman Problem using Dynamic Programming.
# Problem Description:
# Given a set of cities and distances, find the shortest possible route that visits each city once and returns to the starting city.

# %% [markdown]
# #Theory
# TSP uses dynamic programming with bit masking. Store results of visited subsets to reduce repeated work.
#
# ## Algorithm
# 1. Start from source city
# 2. Mark visited cities using bit mask
# 3. Try all unvisited cities
# 4. Choose minimum cost path
# 5. Return to source city

# %%
def tsp(graph):
    n = len(graph)
    dp = [[-1]*(1<<n) for _ in range(n)]

    def visit(city, mask):
        if mask == (1<<n) - 1:
            return graph[city][0]

        if dp[city][mask] != -1:
            return dp[city][mask]

        ans = float('inf')

        for next_city in range(n):
            if mask & (1<<next_city) == 0:
                new_cost = graph[city][next_city] + visit(next_city, mask | (1<<next_city))
                if new_cost < ans:
                    ans = new_cost

        dp[city][mask] = ans
        return ans

    return visit(0, 1)

# %%
ZZgraph = [
[0, 10, 15, 20],
[10, 0, 35, 25],
[15, 35, 0, 30],
[20, 25, 30, 0]
]

print("Minimum travelling cost:", tsp(graph))
# Out:
# Minimum travelling cost: 80

# %% [markdown]
# # Exercise
# 1. Print path of cities visited
# 2. Take graph input from user
# 3. Test with different number of cities

# %%
def get_user_graph_input():
    while True:
        try:
            n = int(input("Enter the number of cities (n): "))
            if n <= 1:
                print("Number of cities must be at least 2.")
                continue
            break
        except ValueError:
            print("Invalid input. Please enter an integer.")

    print(f"Enter the {n}x{n} adjacency matrix row by row. Use spaces to separate values.")
    print("Example for 3 cities: '0 10 15' (for the first row)")

    user_graph = []
    for i in range(n):
        while True:
            try:
                row_str = input(f"Enter row {i+1}: ")
                row_values = list(map(int, row_str.split()))
                if len(row_values) != n:
                    print(f"Row must contain exactly {n} values. Please try again.")
                else:
                    user_graph.append(row_values)
                    break
            except ValueError:
                print("Invalid input. Please ensure all values are integers.")
    return user_graph

user_defined_graph = get_user_graph_input()
min_cost_user, path_user = tsp(user_defined_graph)
print("\nMinimum travelling cost for user-defined graph:", min_cost_user)
print("Optimal path for user-defined graph:", path_user)
# Out:
# Enter the number of cities (n): 3
# Enter the 3x3 adjacency matrix row by row. Use spaces to separate values.
# Example for 3 cities: '0 10 15' (for the first row)
# Enter row 1: '0,10,15'
# Invalid input. Please ensure all values are integers.
# Enter row 1: '0 10 15'
# Invalid input. Please ensure all values are integers.

# %%
graph_3_cities = [
    [0, 10, 15],
    [10, 0, 20],
    [15, 20, 0]
]

min_cost_3, path_3 = tsp(graph_3_cities)
print("Minimum travelling cost for 3 cities:", min_cost_3)
print("Optimal path for 3 cities:", path_3)

# %%
graph_5_cities = [
    [0, 20, 42, 35, 25],
    [20, 0, 30, 34, 12],
    [42, 30, 0, 10, 20],
    [35, 34, 10, 0, 15],
    [25, 12, 20, 15, 0]
]

min_cost_5, path_5 = tsp(graph_5_cities)
print("Minimum travelling cost for 5 cities:", min_cost_5)
print("Optimal path for 5 cities:", path_5)
